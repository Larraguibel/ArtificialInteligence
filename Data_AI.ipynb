# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# The first 3 rows is data for the diagonal heuristic
#
#     -first row is the number of moves
#
#     -second row is true if the game reach a tile of 2048
#
#     -third row is the high score
#
# The last 3 rows is data for the snake heuristic
#
#     -fourth row is the number of moves
#
#     -fifth row is true if the game reach a tile of 2048
#
#     -sixth row is the high score

# %%
diag_move_count =  [2.7950e+03, 1.5050e+03, 9.4500e+02, 1.8770e+03, 8.2500e+02, 8.4700e+02,
                    1.9820e+03, 7.8200e+02, 1.6840e+03, 1.4060e+03, 1.4880e+03, 1.0410e+03,
                    1.2660e+03, 7.6700e+02, 1.3360e+03, 7.3600e+02, 1.6010e+03, 9.3100e+02,
                    5.2700e+02, 1.7330e+03, 9.5500e+02, 9.5700e+02, 5.4600e+02, 9.7300e+02,
                    8.4700e+02, 2.1230e+03, 1.2910e+03, 1.4020e+03, 1.7710e+03, 9.4400e+02,
                    1.4510e+03, 1.4710e+03, 1.8510e+03, 9.6800e+02, 1.8330e+03, 1.4000e+03,
                    5.4400e+02, 9.3400e+02, 9.8300e+02, 4.1000e+02, 2.8030e+03, 2.8800e+03,
                    3.0600e+02, 9.6500e+02, 1.4380e+03, 9.3700e+02, 9.7400e+02, 7.6800e+02,
                    1.6890e+03, 1.5270e+03, 7.8200e+02, 1.0430e+03, 1.8960e+03, 1.5650e+03,
                    1.5980e+03, 8.1800e+02, 9.1500e+02, 1.8990e+03, 1.6140e+03, 1.7220e+03,
                    8.5600e+02, 1.3970e+03, 7.3600e+02, 1.4920e+03, 1.6300e+03, 9.6000e+02,
                    1.0750e+03, 1.6730e+03, 1.9280e+03, 1.6830e+03, 1.0230e+03, 5.4800e+02,
                    2.9100e+02, 3.8500e+02, 1.3930e+03, 1.9910e+03, 3.2200e+02, 8.2800e+02,
                    1.5510e+03, 1.4900e+03, 8.7800e+02, 1.8830e+03, 1.2520e+03, 9.4300e+02,
                    2.1740e+03, 1.3560e+03, 2.4070e+03, 9.6900e+02, 1.4690e+03, 3.9400e+02,
                    4.9600e+02, 1.8910e+03, 1.9000e+03, 9.1100e+02, 1.2160e+03, 8.7300e+02,
                    1.4130e+03, 1.8410e+03, 5.6700e+02, 1.6930e+03]


diag_reach_game = [1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
                    1.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00,
                    0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
                    0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
                    0.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00,
                    1.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00,
                    0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00,
                    0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
                    1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00,
                    1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
                    0.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00,
                    0.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
                    0.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
                    1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00,
                    1.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
                    0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
                    1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00]


diag_score = [5.9580e+04, 2.8320e+04, 1.6152e+04, 3.6248e+04, 1.4256e+04, 1.4476e+04,
              3.7836e+04, 1.3676e+04, 3.2616e+04, 2.7140e+04, 2.8180e+04, 1.7580e+04,
              2.1136e+04, 1.2828e+04, 2.5880e+04, 1.2416e+04, 3.1320e+04, 1.5900e+04,
              7.5200e+03, 3.3312e+04, 1.5940e+04, 1.6136e+04, 7.8600e+03, 1.6440e+04,
              1.4604e+04, 4.7608e+04, 2.5396e+04, 2.7076e+04, 3.4632e+04, 1.6212e+04,
              2.7844e+04, 2.8716e+04, 3.5648e+04, 1.6264e+04, 3.5444e+04, 2.7044e+04,
0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
                    1.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
                    1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
                    1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
                    1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00]

snake_score =  [3.6460e+04, 7.3940e+04, 7.3452e+04, 3.7156e+04, 3.6312e+04, 1.7020e+04,
                2.5380e+04, 3.6408e+04, 7.5528e+04, 3.7008e+04, 5.4568e+04, 7.4840e+03,
                4.1088e+04, 1.2808e+04, 5.9632e+04, 3.4072e+04, 4.7896e+04, 3.4172e+04,
                3.6452e+04, 3.7088e+04, 1.5872e+04, 2.7528e+04, 2.6332e+04, 8.4920e+03,
                3.6412e+04, 3.3328e+04, 3.3744e+04, 3.7180e+04, 3.6760e+04, 3.6348e+04,
                8.0016e+04, 3.6540e+04, 6.1276e+04, 5.1888e+04, 3.1976e+04, 3.4436e+04,
                3.7240e+04, 6.0836e+04, 1.6272e+04, 1.7936e+04, 6.0100e+04, 2.3568e+04,
                6.2420e+04, 3.1948e+04, 3.5712e+04, 5.0612e+04, 7.8460e+04, 4.9688e+04,
                3.5252e+04, 3.7276e+04, 1.6372e+04, 3.7164e+04, 3.6276e+04, 3.2572e+04,
                3.7320e+04, 3.1000e+04, 1.3548e+04, 1.6740e+04, 6.7824e+04, 2.7728e+04,
                3.7372e+04, 3.4652e+04, 3.5512e+04, 6.1156e+04, 3.6392e+04, 3.3176e+04,
                1.6112e+04, 1.6208e+04, 2.3180e+04, 3.4288e+04, 3.2624e+04, 2.2488e+04,
                2.9904e+04, 3.4840e+03, 5.9264e+04, 2.7504e+04, 6.1252e+04, 2.4400e+04,
                3.5444e+04, 5.6916e+04, 3.6444e+04, 2.3524e+04, 1.1416e+04, 3.4808e+04,
                6.7496e+04, 3.3408e+04, 3.6444e+04, 3.6072e+04, 6.0500e+04, 3.6028e+04,
                3.5456e+04, 2.7480e+04, 3.6176e+04, 5.6564e+04, 2.8120e+04, 4.7156e+04,
                3.6124e+04, 3.4584e+04, 1.6140e+04, 2.7536e+04]

# %%
mean_diag_score = np.mean(diag_score)
sd_diag_score = np.std(diag_score)
diag_max = np.max(diag_score)

mean_snake_score = np.mean(snake_score)
sd_snake_score = np.std(snake_score)
snake_max = np.max(snake_score)
print(

f'''
diag_mean, diag_std, diag_max: {round(mean_diag_score, 2), round(sd_diag_score, 2), round(diag_max, 2)}

snake_mean, snake_std, snake_max: {round(mean_snake_score, 2), round(sd_snake_score, 2), round(snake_max, 2)}

''')
# Out:
# diag_mean, diag_std, diag_max: (24042.2, 12572.19, 61464.0)
#
# snake_mean, snake_std, snake_max: (37187.2, 16417.18, 80016.0)

# %%
data = [(round(mean_diag_score, 2), round(sd_diag_score, 2), round(diag_max, 2)),
        (round(mean_snake_score, 2), round(sd_snake_score, 2), round(snake_max, 2))]

# Create a bar graph
category_names = ["Expectimax-Diagonal", "Expectimax-Snake"]
fig, ax = plt.subplots()
index = range(len(category_names))
bar_width = 0.2  # Reduce the width to fit all bars properly
opacity = 0.8

rects1 = ax.bar(index, [data[i][0] for i in range(len(data))], bar_width, alpha=opacity, color='skyblue', label='Score mean')
rects2 = ax.bar([i + bar_width for i in index], [data[i][1] for i in range(len(data))], bar_width, alpha=opacity, color='coral', label='Score standard error')
rects3 = ax.bar([i + 2*bar_width for i in index], [data[i][2] for i in range(len(data))], bar_width, alpha=opacity, color='purple', label='Max score')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Values')
ax.set_title('Expectimax Performance')
ax.set_xticks([i + bar_width for i in index])
ax.set_xticklabels(category_names)
ax.legend()

fig.tight_layout()

# Display the plot
plt.show()

# %%
bin_size = 20
plt.hist(diag_score, bins=bin_size, alpha=0.5, label='Diagonal Score')
plt.hist(snake_score, bins=bin_size, alpha=0.5, label='Snake Score')

plt.xlabel('Score')
plt.ylabel('Antal observationer')
plt.title('Histogram af Diagonal og Snake Scores')
plt.legend()

plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(range(len(diag_score)), np.sort(diag_score), 'o-')
plt.plot(range(len(snake_score)), np.sort(snake_score), 'o-')
plt.xlabel('Number of games')
plt.ylabel('Score in a game')
plt.legend(['Diagonal heuristic', 'Snake heuristic'])

# %%
""" esults for depth: 2:
[[2.7950e+03 1.5050e+03 9.4500e+02 1.8770e+03 8.2500e+02 8.4700e+02
  1.9820e+03 7.8200e+02 1.6840e+03 1.4060e+03 1.4880e+03 1.0410e+03
  1.2660e+03 7.6700e+02 1.3360e+03 7.3600e+02 1.6010e+03 9.3100e+02
  5.2700e+02 1.7330e+03 9.5500e+02 9.5700e+02 5.4600e+02 9.7300e+02
  8.4700e+02 2.1230e+03 1.2910e+03 1.4020e+03 1.7710e+03 9.4400e+02
  1.4510e+03 1.4710e+03 1.8510e+03 9.6800e+02 1.8330e+03 1.4000e+03
  5.4400e+02 9.3400e+02 9.8300e+02 4.1000e+02 2.8030e+03 2.8800e+03
  3.0600e+02 9.6500e+02 1.4380e+03 9.3700e+02 9.7400e+02 7.6800e+02
  1.6890e+03 1.5270e+03 7.8200e+02 1.0430e+03 1.8960e+03 1.5650e+03
  1.5980e+03 8.1800e+02 9.1500e+02 1.8990e+03 1.6140e+03 1.7220e+03
  8.5600e+02 1.3970e+03 7.3600e+02 1.4920e+03 1.6300e+03 9.6000e+02
  1.0750e+03 1.6730e+03 1.9280e+03 1.6830e+03 1.0230e+03 5.4800e+02
  2.9100e+02 3.8500e+02 1.3930e+03 1.9910e+03 3.2200e+02 8.2800e+02
  1.5510e+03 1.4900e+03 8.7800e+02 1.8830e+03 1.2520e+03 9.4300e+02
  2.1740e+03 1.3560e+03 2.4070e+03 9.6900e+02 1.4690e+03 3.9400e+02
  4.9600e+02 1.8910e+03 1.9000e+03 9.1100e+02 1.2160e+03 8.7300e+02
  1.4130e+03 1.8410e+03 5.6700e+02 1.6930e+03]
 [1.0000e+00 1.0000e+00 0.0000e+00 1.0000e+00 0.0000e+00 0.0000e+00
  1.0000e+00 0.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00
  0.0000e+00 0.0000e+00 1.0000e+00 0.0000e+00 1.0000e+00 0.0000e+00
  0.0000e+00 1.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
  0.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00
  1.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00 1.0000e+00 1.0000e+00
  0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 1.0000e+00 1.0000e+00
  0.0000e+00 0.0000e+00 1.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
  1.0000e+00 1.0000e+00 0.0000e+00 0.0000e+00 1.0000e+00 1.0000e+00
  1.0000e+00 0.0000e+00 0.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00
  0.0000e+00 1.0000e+00 0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00
  0.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00 0.0000e+00
  0.0000e+00 0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00 0.0000e+00
  1.0000e+00 1.0000e+00 0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00
  1.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00 1.0000e+00 0.0000e+00
  0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00 1.0000e+00 0.0000e+00
  1.0000e+00 1.0000e+00 0.0000e+00 1.0000e+00]
 [5.9580e+04 2.8320e+04 1.6152e+04 3.6248e+04 1.4256e+04 1.4476e+04
  3.7836e+04 1.3676e+04 3.2616e+04 2.7140e+04 2.8180e+04 1.7580e+04
  2.1136e+04 1.2828e+04 2.5880e+04 1.2416e+04 3.1320e+04 1.5900e+04
  7.5200e+03 3.3312e+04 1.5940e+04 1.6136e+04 7.8600e+03 1.6440e+04
